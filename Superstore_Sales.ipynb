# %% [markdown]
# # Importing libraries used for data analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import  seaborn as sns

# %% [markdown]
# # Importing dataset

# %%
db = pd.read_excel("superstore_USA.xlsx")

# %% [markdown]
# ## viewing data from data sets
# to view data in data set you can use three method -:
# 1) use dataset name -> in this method all the record of the dataset will be shown.            EX ->  db
# 2) use head function -> in this method  no of data will be shown from top.                    EX->db.head(5)
# 3) use Tail function -> in this method no of data will be shown from bottom .                 EX->db.Tail(5)

# %%
db.head(5)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %% [markdown]
# # View no of Rows and Columns of data Set

# %%
db.shape
# Out:
# (9426, 24)

# %% [markdown]
# # checking data type of the columns

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9354 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %% [markdown]
# # checking nurmeric  value of data set

# %%
db.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   9426.000000  9426.000000  9426.000000    9426.000000  9426.000000
# mean   20241.015277     0.049628    88.303686      12.795142  1738.422236
# min        2.000000     0.000000     0.990000       0.490000     2.000000
# 25%    19330.250000     0.020000     6.480000       3.192500   898.000000
# 50%    21686.500000     0.050000    20.990000       6.050000  1750.000000
# 75%    24042.750000     0.080000    85.990000      13.990000  2578.750000
# max    26399.000000     0.250000  6783.020000     164.730000  3403.000000
# std     6101.890965     0.031798   281.540982      17.181203   979.167197
#
#        Product Base Margin   Postal Code                     Order Date  \
# count          9354.000000   9426.000000                           9426
# mean              0.512189  52446.327286  2012-03-05 18:33:59.465308672
# min               0.350000   1001.000000            2010-01-01 00:00:00
# ...

# %% [markdown]
# # Checking Missing value in data set.
#
# to check missing value in data set we wiil use isnull() function
# and use sum() function to see all the missing value in fig.

# %%
db.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %% [markdown]
# # filling missing values in data set -:

# %%
db.fillna(value=db["Product Base Margin"].mean(),inplace =True)

# %%
db.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %%
db["order Year"] = db["Order Date"].dt.year

# %% [markdown]
# # Analyzing data and graph creation

# %% [markdown]
# # order priority

# %%
# THIS IS NUMERICAL ANALYSIS OF 'COUNT OF ORDER PRIORITY'
db['Order Priority'].value_counts()               
                                                    # during value count if you only use count() funcition it gives total of the column.
                                                    #if you use value_counts() it give count according to distribution.
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1804
# Critical            1
# Name: count, dtype: int64

# %%
db["Order Priority"].unique()                 # unique () function give us the name of sub-column  from the column
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical '],
#       dtype=object)

# %%
db["Order Priority"]= db["Order Priority"].replace(to_replace = "Critical" ,value = "Critical ")

# %%
# THIS IS GRIPHICAL ANALYSIS OF 'COUNT OF Order Priority"
plt.figure(figsize = (5,3))
sns.countplot(x="Order Priority", data=db)
plt.title("Count of Order Priority")
plt.show()

# %% [markdown]
# # shipping mode

# %%
db["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: count, dtype: int64

# %%
x=db["Ship Mode"].value_counts().index
y= db['Ship Mode'].value_counts().values

# %%
plt.figure(figsize=(5,4))
plt.title("count of ship mode")
plt.pie(y,labels=x,startangle=60,autopct="%0.2f%%")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Ship Mode on basis of Product Categotry

# %%
plt.figure(figsize=(5,3))
plt.title("count of Ship Mode basis on Product Category")
sns.countplot(x="Ship Mode", data= db, hue="Product Category")
plt.show()

# %% [markdown]
# # Customer Segment

# %%
plt.figure(figsize=(6,3))
plt.title("count of customer segment")
sns.countplot(x="Customer Segment",data = db)
plt.show()

# %%
db["Sales"].value_counts().index[:5]
# Out:
# Index([119.86, 46.85, 33.53, 14.53, 80.58], dtype='float64', name='Sales')

# %% [markdown]
# # Mean of Sales

# %%
from numpy import mean

plt.figure(figsize=(5,3))
plt.title(" Average sales based on product category")
sns.barplot(x="Product Category",y="Sales", data= db,estimator=mean)
plt.show()

# %% [markdown]
# # Product Category basis on its sub category

# %%
plt.figure(figsize=(10,6))
plt.title("count of product category basis on office supplies")
sns.countplot(x="Product Category" , data =db[db["Product Category"]=="Office Supplies"] , hue= "Product Sub-Category")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.title("count of product category basis on Furniture")
sns.countplot(x="Product Category" , data =db[db["Product Category"]=="Furniture"] , hue= "Product Sub-Category")
plt.show()

# %%
plt.figure(figsize=(9,5))
plt.title("count of product category basis on Technology")
sns.countplot(x="Product Category" , data =db[db["Product Category"]=="Technology"] , hue= "Product Sub-Category")
plt.show()

# %% [markdown]
# # Product Container

# %%
plt.figure(figsize=(8,5))
plt.title("count of product container based on Product Category")
sns.countplot(x="Product Container" , data = db,hue = "Product Category")
plt.show()

# %% [markdown]
# # Product Base Margin

# %%
plt.figure(figsize=(5,3))
plt.title("Product base margin base on Product catrgory")
sns.barplot(x= "Product Category",y="Product Base Margin",data = db,estimator=sum)
plt.show()

# %% [markdown]
# # Order per year

# %%
plt.figure(figsize=(5,3))
plt.title("count of order per year")
sns.countplot(x= "order Year",data = db)
plt.show()

# %% [markdown]
# # Profit

# %%
plt.figure(figsize=(5,3))
plt.title("Profit basis on product category")
sns.barplot(x="Product Category" , y= "Profit" , data = db, estimator=sum)
plt.show()

# %% [markdown]
# # Tops 5 selling state or provisions

# %%
a = db["State or Province"].value_counts().index[:5]
b=db["State or Province"].value_counts().values[:5]

# %%
plt.figure(figsize=(6,4))
plt.title("Top 5 selling states or province")
plt.pie(b,labels=a, data=db,autopct="%0.2f%%")
plt.show()
